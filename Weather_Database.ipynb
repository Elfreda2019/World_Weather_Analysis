# %%
# Import the dependencies.

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

from citipy import citipy

# Import the requests library.

import requests

# Import the time library and the datetime module from the datetime library 

import time 

from datetime import datetime


# Import the API key.

from Config import weather_api_key

# Import linregress

from scipy.stats import linregress

# %%
# create a set of random longitude and latitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = lat_lngs

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 743

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=295fd0e28a66265b757071d5c5a859c1

# %%
# # Create an empty list to hold the weather data.
# city_data = []
# # Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
# print("-----------------------------")
# # Create counters.
# record_count = 1
# set_count = 1
# # Loop through all the cities in our list.
# for i, city in enumerate(cities):
# # Group cities in sets of 50 for logging purposes.

#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)
#         # Create endpoint URL with each city.
#         city_url = url + "&q=" + city.replace(" ","+")
#         # Log the URL, record, and set numbers and the city.
#         print(f"Processing Record {record_count} of Set {set_count} | {city}")
#         # Add 1 to the record count.
#         record_count += 1
#         # Run an API request for each of the cities.
#         try:
#             # Parse the JSON and retrieve data.
#             city_weather = requests.get(city_url).json()
#             # Parse out the needed data.
#             city_lat = city_weather["coord"]["lat"]
#             city_lng = city_weather["coord"]["lon"]
#             city_max_temp = city_weather["main"]["temp_max"]
#             city_humidity = city_weather["main"]["humidity"]
#             city_clouds = city_weather["clouds"]["all"]
#             city_wind = city_weather["wind"]["speed"]
#             city_country = city_weather["sys"]["country"]
#             city_weather_description = city_weather["weather"][0]["description"]
            
#             #Append the city information into city_data list.
#             city_data.append({"City": city.title(), "Lat": city_lat, "Lng": city_lng, "Max Temp": city_max_temp, "Current Description":city_weather_description, "Humidity": city_humidity,

#                                "Cloudiness": city_clouds, "Wind Speed": city_wind, "Country": city_country})

#             # If an error is experienced, skip the city.
#         except:
#             print("City not found. Skipping...")
#             pass

# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 

        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Current Description":city_weather_description,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | quatre cocos
# Processing Record 2 of Set 1 | fershampenuaz
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | borovichi
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | katsuura
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | sao joao da barra
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | jiuquan
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | mae ramat
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | sorong
# Processing Record 21 of Set 1 | jacareacanga
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | broome
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 1 | egvekinot
# Processing Record 28 of Set 1 | meadow lake
# Processing Record 29 of Set 1 | kawalu
# Processing Record 30 of Set 1 | alofi
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | esperance
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | bilma
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 1 | oranjestad
# Processing Record 40 of Set 1 | port-cartier
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | port angeles
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | nigran
# Processing Record 45 of Set 1 | satinka
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | kupang
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | rayachoti
# Processing Record 50 of Set 1 | severo-kurilsk
# Processing Record 1 of Set 2 | seymchan
# Processing Record 2 of Set 2 | huilong
# Processing Record 3 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | belaya gora
# Processing Record 6 of Set 2 | nkpor
# Processing Record 7 of Set 2 | lazaro cardenas
# Processing Record 8 of Set 2 | fortuna
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | idenao
# Processing Record 15 of Set 2 | mathathane
# Processing Record 16 of Set 2 | aykhal
# Processing Record 17 of Set 2 | dekoa
# City not found. Skipping...
# Processing Record 18 of Set 2 | pangkalanbuun
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | mbouda
# Processing Record 22 of Set 2 | samarai
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | sangar
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | fort nelson
# Processing Record 28 of Set 2 | san juan
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | puerto del rosario
# Processing Record 31 of Set 2 | noumea
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | paracuru
# Processing Record 34 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | saint pete beach
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | nanortalik
# Processing Record 41 of Set 2 | montepuez
# Processing Record 42 of Set 2 | katsina
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | linqiong
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | sechura
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | coruripe
# Processing Record 1 of Set 3 | ucluelet
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | caravelas
# Processing Record 4 of Set 3 | aksha
# Processing Record 5 of Set 3 | bandarbeyla
# Processing Record 6 of Set 3 | okhotsk
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | gbarnga
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | salmas
# Processing Record 11 of Set 3 | pacific grove
# Processing Record 12 of Set 3 | hilo
# Processing Record 13 of Set 3 | thiruvarur
# Processing Record 14 of Set 3 | neryungri
# Processing Record 15 of Set 3 | vila franca do campo
# Processing Record 16 of Set 3 | karachi
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | leua
# Processing Record 19 of Set 3 | mehamn
# Processing Record 20 of Set 3 | jacmel
# Processing Record 21 of Set 3 | faya
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | santiago de cao
# Processing Record 24 of Set 3 | dingle
# Processing Record 25 of Set 3 | saint anthony
# Processing Record 26 of Set 3 | san cristobal
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | acapulco
# Processing Record 30 of Set 3 | chuy
# Processing Record 31 of Set 3 | verkhnevilyuysk
# Processing Record 32 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 33 of Set 3 | ahipara
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | jamestown
# Processing Record 36 of Set 3 | eirunepe
# Processing Record 37 of Set 3 | aklavik
# Processing Record 38 of Set 3 | labuan
# Processing Record 39 of Set 3 | atar
# Processing Record 40 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 3 | saint george
# Processing Record 42 of Set 3 | svetlogorsk
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 3 | port hardy
# Processing Record 46 of Set 3 | kerema
# Processing Record 47 of Set 3 | kavieng
# Processing Record 48 of Set 3 | vanimo
# Processing Record 49 of Set 3 | padang
# Processing Record 50 of Set 3 | yar-sale
# Processing Record 1 of Set 4 | taoudenni
# Processing Record 2 of Set 4 | rusape
# Processing Record 3 of Set 4 | sumter
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 6 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 4 | santa maria
# Processing Record 8 of Set 4 | kinna
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | puerto ayora
# Processing Record 11 of Set 4 | eldorado
# Processing Record 12 of Set 4 | beeville
# Processing Record 13 of Set 4 | zhigansk
# Processing Record 14 of Set 4 | anjozorobe
# Processing Record 15 of Set 4 | saint-francois
# Processing Record 16 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 4 | nova olimpia
# Processing Record 18 of Set 4 | muros
# Processing Record 19 of Set 4 | rocha
# Processing Record 20 of Set 4 | brae
# Processing Record 21 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 4 | souillac
# Processing Record 23 of Set 4 | ambovombe
# Processing Record 24 of Set 4 | belyy yar
# Processing Record 25 of Set 4 | dunedin
# Processing Record 26 of Set 4 | karasjok
# Processing Record 27 of Set 4 | luganville
# Processing Record 28 of Set 4 | calama
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | evensk
# Processing Record 31 of Set 4 | bilibino
# Processing Record 32 of Set 4 | gomoh
# Processing Record 33 of Set 4 | mathbaria
# Processing Record 34 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 4 | cubuk
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | pyapon
# Processing Record 38 of Set 4 | gravesend
# Processing Record 39 of Set 4 | mahibadhoo
# Processing Record 40 of Set 4 | leshukonskoye
# Processing Record 41 of Set 4 | hokitika
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | adrar
# Processing Record 44 of Set 4 | burica
# City not found. Skipping...
# Processing Record 45 of Set 4 | lakhipur
# Processing Record 46 of Set 4 | sakakah
# Processing Record 47 of Set 4 | sakata
# Processing Record 48 of Set 4 | berlevag
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | alta floresta
# Processing Record 3 of Set 5 | horodnya
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | andenes
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | dwarka
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | rawlins
# Processing Record 12 of Set 5 | san
# Processing Record 13 of Set 5 | stepantsevo
# Processing Record 14 of Set 5 | sola
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | kununurra
# Processing Record 17 of Set 5 | port blair
# Processing Record 18 of Set 5 | moree
# Processing Record 19 of Set 5 | wum
# Processing Record 20 of Set 5 | santa isabel do rio negro
# Processing Record 21 of Set 5 | aloleng
# Processing Record 22 of Set 5 | londonderry
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | berwick
# Processing Record 25 of Set 5 | tianpeng
# Processing Record 26 of Set 5 | coahuayana
# Processing Record 27 of Set 5 | fairbanks
# Processing Record 28 of Set 5 | kodiak
# Processing Record 29 of Set 5 | kruisfontein
# Processing Record 30 of Set 5 | jalu
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | upernavik
# Processing Record 33 of Set 5 | juba
# Processing Record 34 of Set 5 | tskneti
# Processing Record 35 of Set 5 | havre-saint-pierre
# Processing Record 36 of Set 5 | billings
# Processing Record 37 of Set 5 | beloha
# Processing Record 38 of Set 5 | inhambane
# Processing Record 39 of Set 5 | kalashnikovo
# Processing Record 40 of Set 5 | zyryanka
# Processing Record 41 of Set 5 | manjeshwar
# Processing Record 42 of Set 5 | dingtao
# Processing Record 43 of Set 5 | wana
# Processing Record 44 of Set 5 | diapaga
# Processing Record 45 of Set 5 | port elizabeth
# Processing Record 46 of Set 5 | ola
# Processing Record 47 of Set 5 | sur
# Processing Record 48 of Set 5 | saskylakh
# Processing Record 49 of Set 5 | duku
# Processing Record 50 of Set 5 | fuyang
# Processing Record 1 of Set 6 | haines junction
# Processing Record 2 of Set 6 | shirokiy
# Processing Record 3 of Set 6 | farafenni
# Processing Record 4 of Set 6 | omboue
# Processing Record 5 of Set 6 | nome
# Processing Record 6 of Set 6 | karratha
# Processing Record 7 of Set 6 | san quintin
# Processing Record 8 of Set 6 | terrace
# Processing Record 9 of Set 6 | sao gabriel da cachoeira
# Processing Record 10 of Set 6 | bethel
# Processing Record 11 of Set 6 | salinas
# Processing Record 12 of Set 6 | adra
# Processing Record 13 of Set 6 | georgetown
# Processing Record 14 of Set 6 | umm lajj
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | tonekabon
# Processing Record 17 of Set 6 | chapais
# Processing Record 18 of Set 6 | grimari
# City not found. Skipping...
# Processing Record 19 of Set 6 | touros
# Processing Record 20 of Set 6 | srednekolymsk
# Processing Record 21 of Set 6 | sarakhs
# Processing Record 22 of Set 6 | waipawa
# Processing Record 23 of Set 6 | bobo dioulasso
# Processing Record 24 of Set 6 | ozinki
# Processing Record 25 of Set 6 | santa rosa
# Processing Record 26 of Set 6 | novyy yegorlyk
# Processing Record 27 of Set 6 | singaraja
# Processing Record 28 of Set 6 | hun
# Processing Record 29 of Set 6 | puerto quijarro
# Processing Record 30 of Set 6 | tura
# Processing Record 31 of Set 6 | tasiilaq
# Processing Record 32 of Set 6 | roma
# Processing Record 33 of Set 6 | meridian
# Processing Record 34 of Set 6 | lensk
# Processing Record 35 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 6 | sakaiminato
# Processing Record 37 of Set 6 | yarada
# Processing Record 38 of Set 6 | trairi
# Processing Record 39 of Set 6 | simao
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | kwinana
# Processing Record 42 of Set 6 | pangnirtung
# Processing Record 43 of Set 6 | vila velha
# Processing Record 44 of Set 6 | lagoa
# Processing Record 45 of Set 6 | bereda
# Processing Record 46 of Set 6 | saint-joseph
# Processing Record 47 of Set 6 | port keats
# Processing Record 48 of Set 6 | mabaruma
# Processing Record 49 of Set 6 | penzance
# Processing Record 50 of Set 6 | piacabucu
# Processing Record 1 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 7 | togur
# Processing Record 3 of Set 7 | hirara
# Processing Record 4 of Set 7 | aranda de duero
# Processing Record 5 of Set 7 | kailua
# Processing Record 6 of Set 7 | farah
# Processing Record 7 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 7 | chitipa
# Processing Record 9 of Set 7 | cherskiy
# Processing Record 10 of Set 7 | lumphat
# Processing Record 11 of Set 7 | teknaf
# Processing Record 12 of Set 7 | marrakesh
# Processing Record 13 of Set 7 | leningradskiy
# Processing Record 14 of Set 7 | harper
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | winnemucca
# Processing Record 17 of Set 7 | goulburn
# Processing Record 18 of Set 7 | tual
# Processing Record 19 of Set 7 | moindou
# Processing Record 20 of Set 7 | svetlyy
# Processing Record 21 of Set 7 | olinda
# Processing Record 22 of Set 7 | komsomolskiy
# Processing Record 23 of Set 7 | sabang
# Processing Record 24 of Set 7 | ishigaki
# Processing Record 25 of Set 7 | nadym
# Processing Record 26 of Set 7 | vitim
# Processing Record 27 of Set 7 | bassila
# Processing Record 28 of Set 7 | ayer itam
# City not found. Skipping...
# Processing Record 29 of Set 7 | kieta
# Processing Record 30 of Set 7 | kiunga
# Processing Record 31 of Set 7 | byron bay
# Processing Record 32 of Set 7 | puerto escondido
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | udachnyy
# Processing Record 35 of Set 7 | dergachi
# Processing Record 36 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 37 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 7 | arman
# Processing Record 39 of Set 7 | ouargaye
# Processing Record 40 of Set 7 | pimentel
# Processing Record 41 of Set 7 | anadyr
# Processing Record 42 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 43 of Set 7 | lusambo
# Processing Record 44 of Set 7 | geraldton
# Processing Record 45 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 7 | norman wells
# Processing Record 47 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 7 | rongcheng
# Processing Record 49 of Set 7 | xinan
# Processing Record 50 of Set 7 | puerto santander
# Processing Record 1 of Set 8 | makinsk
# Processing Record 2 of Set 8 | codrington
# Processing Record 3 of Set 8 | portland
# Processing Record 4 of Set 8 | nybro
# Processing Record 5 of Set 8 | birao
# Processing Record 6 of Set 8 | yerbogachen
# Processing Record 7 of Set 8 | mao
# Processing Record 8 of Set 8 | richards bay
# Processing Record 9 of Set 8 | nefteyugansk
# Processing Record 10 of Set 8 | can tho
# Processing Record 11 of Set 8 | talnakh
# Processing Record 12 of Set 8 | georgiyevka
# Processing Record 13 of Set 8 | vikulovo
# Processing Record 14 of Set 8 | nawada
# Processing Record 15 of Set 8 | iranshahr
# Processing Record 16 of Set 8 | husavik
# Processing Record 17 of Set 8 | hailar
# Processing Record 18 of Set 8 | mayo
# Processing Record 19 of Set 8 | hasaki
# Processing Record 20 of Set 8 | jiexiu
# Processing Record 21 of Set 8 | ahuimanu
# Processing Record 22 of Set 8 | makakilo city
# Processing Record 23 of Set 8 | police
# Processing Record 24 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 8 | qui nhon
# Processing Record 26 of Set 8 | pisco
# Processing Record 27 of Set 8 | avera
# Processing Record 28 of Set 8 | fairview
# Processing Record 29 of Set 8 | leh
# Processing Record 30 of Set 8 | raposa
# Processing Record 31 of Set 8 | agadez
# Processing Record 32 of Set 8 | numan
# Processing Record 33 of Set 8 | maltahohe
# Processing Record 34 of Set 8 | bukachacha
# Processing Record 35 of Set 8 | chernyshevskiy
# Processing Record 36 of Set 8 | atakpame
# Processing Record 37 of Set 8 | witu
# Processing Record 38 of Set 8 | paciran
# Processing Record 39 of Set 8 | palmer
# Processing Record 40 of Set 8 | xudat
# Processing Record 41 of Set 8 | qaqortoq
# Processing Record 42 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 8 | banjar
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | seoul
# Processing Record 46 of Set 8 | hamilton
# Processing Record 47 of Set 8 | tiznit
# Processing Record 48 of Set 8 | dourbali
# Processing Record 49 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 50 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 9 | necochea
# Processing Record 2 of Set 9 | ust-nera
# Processing Record 3 of Set 9 | jupiter
# Processing Record 4 of Set 9 | namatanai
# Processing Record 5 of Set 9 | santa maria del oro
# Processing Record 6 of Set 9 | suntar
# Processing Record 7 of Set 9 | panjab
# Processing Record 8 of Set 9 | kathu
# Processing Record 9 of Set 9 | komatipoort
# Processing Record 10 of Set 9 | jilib
# Processing Record 11 of Set 9 | ponta do sol
# Processing Record 12 of Set 9 | emporia
# Processing Record 13 of Set 9 | synya
# Processing Record 14 of Set 9 | fukue
# Processing Record 15 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 9 | asau
# Processing Record 17 of Set 9 | tanete
# Processing Record 18 of Set 9 | keetmanshoop
# Processing Record 19 of Set 9 | tanout
# Processing Record 20 of Set 9 | sao felix do xingu
# Processing Record 21 of Set 9 | kahului
# Processing Record 22 of Set 9 | merauke
# Processing Record 23 of Set 9 | grand falls
# Processing Record 24 of Set 9 | buraydah
# Processing Record 25 of Set 9 | shingu
# Processing Record 26 of Set 9 | kalmar
# Processing Record 27 of Set 9 | moranbah
# Processing Record 28 of Set 9 | nuuk
# Processing Record 29 of Set 9 | buala
# Processing Record 30 of Set 9 | bougouni
# Processing Record 31 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 9 | tiksi
# Processing Record 33 of Set 9 | lapua
# Processing Record 34 of Set 9 | rawson
# Processing Record 35 of Set 9 | lakes entrance
# Processing Record 36 of Set 9 | namibe
# Processing Record 37 of Set 9 | ostrovnoy
# Processing Record 38 of Set 9 | blagoyevo
# Processing Record 39 of Set 9 | joensuu
# Processing Record 40 of Set 9 | luderitz
# Processing Record 41 of Set 9 | itoman
# Processing Record 42 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 44 of Set 9 | mount isa
# Processing Record 45 of Set 9 | troitsko-pechorsk
# Processing Record 46 of Set 9 | sayula
# Processing Record 47 of Set 9 | zaysan
# Processing Record 48 of Set 9 | muroto
# Processing Record 49 of Set 9 | boden
# Processing Record 50 of Set 9 | nalut
# Processing Record 1 of Set 10 | nueva armenia
# Processing Record 2 of Set 10 | iki-burul
# Processing Record 3 of Set 10 | goundi
# Processing Record 4 of Set 10 | amarante do maranhao
# Processing Record 5 of Set 10 | iqaluit
# Processing Record 6 of Set 10 | bambari
# Processing Record 7 of Set 10 | tarko-sale
# Processing Record 8 of Set 10 | cayenne
# Processing Record 9 of Set 10 | la esperanza
# Processing Record 10 of Set 10 | saint-augustin
# Processing Record 11 of Set 10 | walvis bay
# Processing Record 12 of Set 10 | marataizes
# Processing Record 13 of Set 10 | houlton
# Processing Record 14 of Set 10 | riyadh
# Processing Record 15 of Set 10 | otane
# Processing Record 16 of Set 10 | tabou
# Processing Record 17 of Set 10 | coihaique
# Processing Record 18 of Set 10 | tugulym
# Processing Record 19 of Set 10 | esmeraldas
# Processing Record 20 of Set 10 | port shepstone
# Processing Record 21 of Set 10 | nizhniy kuranakh
# Processing Record 22 of Set 10 | zhangye
# Processing Record 23 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 10 | carutapera
# Processing Record 25 of Set 10 | hayden
# Processing Record 26 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 27 of Set 10 | tiarei
# Processing Record 28 of Set 10 | mul
# Processing Record 29 of Set 10 | porto novo
# Processing Record 30 of Set 10 | port hedland
# Processing Record 31 of Set 10 | dakar
# Processing Record 32 of Set 10 | ribeira brava
# Processing Record 33 of Set 10 | turmalina
# Processing Record 34 of Set 10 | hearst
# Processing Record 35 of Set 10 | hofn
# Processing Record 36 of Set 10 | tres barras
# Processing Record 37 of Set 10 | porto belo
# Processing Record 38 of Set 10 | cocorit
# Processing Record 39 of Set 10 | genhe
# Processing Record 40 of Set 10 | smithers
# Processing Record 41 of Set 10 | cap malheureux
# Processing Record 42 of Set 10 | da nang
# Processing Record 43 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 10 | puerto ayacucho
# Processing Record 45 of Set 10 | bac lieu
# Processing Record 46 of Set 10 | mulchen
# Processing Record 47 of Set 10 | laramie
# Processing Record 48 of Set 10 | poso
# Processing Record 49 of Set 10 | liverpool
# Processing Record 50 of Set 10 | okha
# Processing Record 1 of Set 11 | catamarca
# Processing Record 2 of Set 11 | cockburn town
# Processing Record 3 of Set 11 | los llanos de aridane
# Processing Record 4 of Set 11 | kalispell
# Processing Record 5 of Set 11 | tago
# Processing Record 6 of Set 11 | muana
# Processing Record 7 of Set 11 | hay river
# Processing Record 8 of Set 11 | kem
# Processing Record 9 of Set 11 | oktyabrskiy
# Processing Record 10 of Set 11 | bandipur
# Processing Record 11 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 11 | nelson bay
# Processing Record 13 of Set 11 | hienghene
# Processing Record 14 of Set 11 | mamallapuram
# Processing Record 15 of Set 11 | san policarpo
# Processing Record 16 of Set 11 | lompoc
# Processing Record 17 of Set 11 | isla vista
# Processing Record 18 of Set 11 | matara
# Processing Record 19 of Set 11 | dareda
# Processing Record 20 of Set 11 | takaungu
# Processing Record 21 of Set 11 | kijang
# Processing Record 22 of Set 11 | calvia
# Processing Record 23 of Set 11 | mweka
# Processing Record 24 of Set 11 | vytegra
# Processing Record 25 of Set 11 | bernburg
# Processing Record 26 of Set 11 | goderich
# Processing Record 27 of Set 11 | marsa matruh
# Processing Record 28 of Set 11 | tabas
# Processing Record 29 of Set 11 | sinnamary
# Processing Record 30 of Set 11 | san patricio
# Processing Record 31 of Set 11 | balakhta
# Processing Record 32 of Set 11 | cedar city
# Processing Record 33 of Set 11 | lufilufi
# Processing Record 34 of Set 11 | hohhot
# Processing Record 35 of Set 11 | tahta
# Processing Record 36 of Set 11 | lagos
# Processing Record 37 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 11 | saint-pierre
# Processing Record 39 of Set 11 | port lincoln
# Processing Record 40 of Set 11 | saraza
# Processing Record 41 of Set 11 | khovu-aksy
# Processing Record 42 of Set 11 | shwebo
# Processing Record 43 of Set 11 | aras
# Processing Record 44 of Set 11 | buta
# Processing Record 45 of Set 11 | gweta
# Processing Record 46 of Set 11 | bonthe
# Processing Record 47 of Set 11 | okato
# Processing Record 48 of Set 11 | riviere-au-renard
# Processing Record 49 of Set 11 | agdas
# Processing Record 50 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 12 | abidjan
# Processing Record 2 of Set 12 | southbridge
# Processing Record 3 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 4 of Set 12 | springdale
# Processing Record 5 of Set 12 | peterhead
# Processing Record 6 of Set 12 | doha
# Processing Record 7 of Set 12 | jasper
# Processing Record 8 of Set 12 | menongue
# Processing Record 9 of Set 12 | guarapari
# Processing Record 10 of Set 12 | pedernales
# Processing Record 11 of Set 12 | comodoro rivadavia
# Processing Record 12 of Set 12 | gari
# Processing Record 13 of Set 12 | mount gambier
# Processing Record 14 of Set 12 | bridlington
# Processing Record 15 of Set 12 | novosokolniki
# Processing Record 16 of Set 12 | batticaloa
# Processing Record 17 of Set 12 | hjelset
# Processing Record 18 of Set 12 | vila do maio
# Processing Record 19 of Set 12 | nyimba
# Processing Record 20 of Set 12 | polunochnoye
# Processing Record 21 of Set 12 | laguna
# Processing Record 22 of Set 12 | gilgit
# Processing Record 23 of Set 12 | murgab
# Processing Record 24 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 12 | nouadhibou
# Processing Record 26 of Set 12 | khani
# Processing Record 27 of Set 12 | urazovo
# Processing Record 28 of Set 12 | ajaccio
# Processing Record 29 of Set 12 | miramar
# Processing Record 30 of Set 12 | yerofey pavlovich
# Processing Record 31 of Set 12 | ingham
# Processing Record 32 of Set 12 | shibetsu
# Processing Record 33 of Set 12 | teya
# Processing Record 34 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 12 | petrovsk-zabaykalskiy
# Processing Record 36 of Set 12 | natal
# Processing Record 37 of Set 12 | ambilobe
# Processing Record 38 of Set 12 | trinidad
# Processing Record 39 of Set 12 | rykhtychi
# Processing Record 40 of Set 12 | denpasar
# Processing Record 41 of Set 12 | alice springs
# Processing Record 42 of Set 12 | binzhou
# Processing Record 43 of Set 12 | vernon
# Processing Record 44 of Set 12 | le port
# Processing Record 45 of Set 12 | tuensang
# Processing Record 46 of Set 12 | huarmey
# Processing Record 47 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 12 | paita
# Processing Record 49 of Set 12 | russell
# Processing Record 50 of Set 12 | parfenyevo
# Processing Record 1 of Set 13 | te anau
# Processing Record 2 of Set 13 | san rafael
# Processing Record 3 of Set 13 | yantal
# Processing Record 4 of Set 13 | zhicheng
# Processing Record 5 of Set 13 | atambua
# Processing Record 6 of Set 13 | krasnoselkup
# Processing Record 7 of Set 13 | suzun
# Processing Record 8 of Set 13 | churapcha
# Processing Record 9 of Set 13 | choya
# Processing Record 10 of Set 13 | puyang
# Processing Record 11 of Set 13 | westport
# Processing Record 12 of Set 13 | mishan
# Processing Record 13 of Set 13 | lavrentiya
# Processing Record 14 of Set 13 | tomatlan
# Processing Record 15 of Set 13 | taltal
# Processing Record 16 of Set 13 | kharovsk
# Processing Record 17 of Set 13 | tehachapi
# Processing Record 18 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 13 | do rud
# City not found. Skipping...
# Processing Record 20 of Set 13 | biala podlaska
# Processing Record 21 of Set 13 | springfield
# Processing Record 22 of Set 13 | turhal
# Processing Record 23 of Set 13 | merritt island
# Processing Record 24 of Set 13 | banda aceh
# Processing Record 25 of Set 13 | bella vista
# Processing Record 26 of Set 13 | nabire
# Processing Record 27 of Set 13 | thunder bay
# Processing Record 28 of Set 13 | boende
# Processing Record 29 of Set 13 | schwerin
# Processing Record 30 of Set 13 | romny
# Processing Record 31 of Set 13 | tigil
# Processing Record 32 of Set 13 | narasannapeta
# Processing Record 33 of Set 13 | zabaykalsk
# Processing Record 34 of Set 13 | fenoarivo atsinanana
# Processing Record 35 of Set 13 | lewiston
# Processing Record 36 of Set 13 | gazojak
# Processing Record 37 of Set 13 | sao jose da coroa grande
# Processing Record 38 of Set 13 | tuy hoa
# Processing Record 39 of Set 13 | urengoy
# Processing Record 40 of Set 13 | lugovoy
# Processing Record 41 of Set 13 | general nakar
# Processing Record 42 of Set 13 | vestmannaeyjar
# Processing Record 43 of Set 13 | warrnambool
# Processing Record 44 of Set 13 | shellbrook
# Processing Record 45 of Set 13 | sultanpur
# Processing Record 46 of Set 13 | tukrah
# Processing Record 47 of Set 13 | verkhoyansk
# Processing Record 48 of Set 13 | painesville
# Processing Record 49 of Set 13 | kalemie
# Processing Record 50 of Set 13 | pareora
# Processing Record 1 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 14 | kamenka
# Processing Record 3 of Set 14 | port moresby
# Processing Record 4 of Set 14 | najran
# Processing Record 5 of Set 14 | neuquen
# Processing Record 6 of Set 14 | ilulissat
# Processing Record 7 of Set 14 | grand gaube
# Processing Record 8 of Set 14 | verkh-usugli
# Processing Record 9 of Set 14 | kolokani
# Processing Record 10 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 11 of Set 14 | meiganga
# Processing Record 12 of Set 14 | the valley
# Processing Record 13 of Set 14 | juneau
# Processing Record 14 of Set 14 | batagay-alyta
# Processing Record 15 of Set 14 | uyemskiy
# Processing Record 16 of Set 14 | nador
# Processing Record 17 of Set 14 | oistins
# Processing Record 18 of Set 14 | maldonado
# Processing Record 19 of Set 14 | conceicao da barra
# Processing Record 20 of Set 14 | lydenburg
# Processing Record 21 of Set 14 | saint-denis
# Processing Record 22 of Set 14 | north branch
# Processing Record 23 of Set 14 | tatawin
# Processing Record 24 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 25 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 14 | majene
# Processing Record 27 of Set 14 | santiago de cuba
# Processing Record 28 of Set 14 | bentiu
# Processing Record 29 of Set 14 | cururupu
# Processing Record 30 of Set 14 | pangoa
# Processing Record 31 of Set 14 | abu dhabi
# Processing Record 32 of Set 14 | longhua
# Processing Record 33 of Set 14 | pangody
# Processing Record 34 of Set 14 | muzaffarabad
# Processing Record 35 of Set 14 | pizarro
# Processing Record 36 of Set 14 | balad
# Processing Record 37 of Set 14 | dauphin
# Processing Record 38 of Set 14 | ugra
# Processing Record 39 of Set 14 | umm kaddadah
# Processing Record 40 of Set 14 | kedrovyy
# Processing Record 41 of Set 14 | abengourou
# Processing Record 42 of Set 14 | pocatello
# Processing Record 43 of Set 14 | mastic beach
# Processing Record 44 of Set 14 | linfen
# Processing Record 45 of Set 14 | kipini
# Processing Record 46 of Set 14 | buchanan
# Processing Record 47 of Set 14 | saryozek
# Processing Record 48 of Set 14 | tocopilla
# Processing Record 49 of Set 14 | kaeo
# Processing Record 50 of Set 14 | tashtagol
# Processing Record 1 of Set 15 | solginskiy
# Processing Record 2 of Set 15 | strezhevoy
# Processing Record 3 of Set 15 | songea
# Processing Record 4 of Set 15 | gighera
# Processing Record 5 of Set 15 | pacifica
# Processing Record 6 of Set 15 | mbala
# Processing Record 7 of Set 15 | poum
# Processing Record 8 of Set 15 | dondo
# Processing Record 9 of Set 15 | sembe
# Processing Record 10 of Set 15 | tucurui
# Processing Record 11 of Set 15 | zverinogolovskoye
# Processing Record 12 of Set 15 | margate
# Processing Record 13 of Set 15 | kozhva
# Processing Record 14 of Set 15 | bogatoye
# Processing Record 15 of Set 15 | sabaudia
# Processing Record 16 of Set 15 | magadan
# Processing Record 17 of Set 15 | dunmore town
# Processing Record 18 of Set 15 | moratuwa
# Processing Record 19 of Set 15 | ayan
# Processing Record 20 of Set 15 | darhan
# Processing Record 21 of Set 15 | freeport
# Processing Record 22 of Set 15 | luorong
# Processing Record 23 of Set 15 | reitz
# Processing Record 24 of Set 15 | gornopravdinsk
# Processing Record 25 of Set 15 | yenagoa
# Processing Record 26 of Set 15 | moglingen
# Processing Record 27 of Set 15 | aragarcas
# Processing Record 28 of Set 15 | kargasok
# Processing Record 29 of Set 15 | sabha
# Processing Record 30 of Set 15 | mapiripan
# Processing Record 31 of Set 15 | broken hill
# Processing Record 32 of Set 15 | vostok
# Processing Record 33 of Set 15 | kudahuvadhoo
# Processing Record 34 of Set 15 | awjilah
# Processing Record 35 of Set 15 | ngorongoro
# Processing Record 36 of Set 15 | vao
# Processing Record 37 of Set 15 | anloga
# Processing Record 38 of Set 15 | gushikawa
# Processing Record 39 of Set 15 | nuristan
# Processing Record 40 of Set 15 | hibbing
# Processing Record 41 of Set 15 | llanes
# Processing Record 42 of Set 15 | ternate
# Processing Record 43 of Set 15 | gataivai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity Current Description  \
# 0   Quatre Cocos -20.2078   57.7625     70.09        68       broken clouds
# 1  Fershampenuaz  53.5202   59.8117     70.47        63       broken clouds
# 2          Bluff -46.6000  168.3333     44.80        66     overcast clouds
# 3         Hobart -42.8794  147.3294     44.46        76     overcast clouds
# 4         Atuona  -9.8000 -139.0333     77.27        77          light rain
# 5     Butaritari   3.0707  172.7902     81.18        79          light rain
# 6      Borovichi  58.3878   33.9155     70.84        44    scattered clouds
# 7   Punta Arenas -53.1500  -70.9167     42.91        81           clear sky
# 8    Tuktoyaktuk  69.4541 -133.0374     41.23        94          light rain
# 9       Katsuura  35.1333  140.3000     80.13        90     overcast clouds
#
#    Cloudiness  Wind Speed Country
# 0          58       22.46      MU
# 1          74        4.85      RU
# 2          99        9.80      NZ
# 3         100        9.22      AU
# 4          41       22.41      PF
# 5          98       14.61      KI
# 6          48        4.23      RU
# 7           0       14.97      CL
# 8         100       17.18      CA
# 9          97       13.98      JP

# %%
# reorder the columns 

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]


city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Quatre Cocos      MU -20.2078   57.7625     70.09        68          58
# 1  Fershampenuaz      RU  53.5202   59.8117     70.47        63          74
# 2          Bluff      NZ -46.6000  168.3333     44.80        66          99
# 3         Hobart      AU -42.8794  147.3294     44.46        76         100
# 4         Atuona      PF  -9.8000 -139.0333     77.27        77          41
# 5     Butaritari      KI   3.0707  172.7902     81.18        79          98
# 6      Borovichi      RU  58.3878   33.9155     70.84        44          48
# 7   Punta Arenas      CL -53.1500  -70.9167     42.91        81           0
# 8    Tuktoyaktuk      CA  69.4541 -133.0374     41.23        94         100
# 9       Katsuura      JP  35.1333  140.3000     80.13        90          97
#
#    Wind Speed Current Description
# 0       22.46       broken clouds
# 1        4.85       broken clouds
# 2        9.80     overcast clouds
# 3        9.22     overcast clouds
# 4       22.41          light rain
# 5       14.61          light rain
# 6        4.23    scattered clouds
# 7       14.97           clear sky
# 8       17.18          light rain
# 9       13.98     overcast clouds

# %%
# Create the output file (CSV).


output_data_file = "Weather_Database/WeatherPy_Database.csv"


# Export the City_Data into a CSV.


city_data_df.to_csv(output_data_file, index_label="City_ID")
